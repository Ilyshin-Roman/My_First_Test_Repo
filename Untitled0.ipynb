# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilyshin-Roman/My_First_Test_Repo/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Пример использования Markdown

# %% [markdown]
# Нужно сделать:
# 1. Список
# 2. Рисунок
# 3. Таблицу
# 4. Ссылку

# %% [markdown]
# ![a4a0c3406c65548ae368985e3f35bf3c.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# First column name  | Second column name
# -------------------|------------------
# Row 1, Col 1       | Row 1, Col 2
# Row 2, Col 1       | Row 2, Col 2
#
# ---

# %% [markdown]
# [Ссылка на руководство](https://colab.research.google.com/notebooks/markdown_guide.ipynb#scrollTo=Lhfnlq1Surtk)

# %% [markdown]
# First column name  | Second column name
# -------------------|------------------
# Row 1, Col 1       | Row 1, Col 2
# Row 2, Col 1       | Row 2, Col 2
#
# ---
